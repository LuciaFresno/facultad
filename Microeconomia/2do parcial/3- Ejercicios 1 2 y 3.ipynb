# %% [markdown]
# # Teoría del Productor
#
# Guia: https://drive.google.com/file/d/1pmR8dMCCnapUQ-cDk-IiOvqhXYIiz35_/view?usp=sharing
#
# ### Ejercicio 1
#
# 1.- Producción con un insumo variable
# 1.1. Dada la siguiente función de producto total (curva de productividad) para el insumo A
# 2 3 PT a a   100. , se pide:
# a) ¿Cuál es la función del PMg del insumo A? ¿A partir de qué nivel de utilización
# del insumo A comenzaría a hacerse presente el rendimiento marginal
# decreciente?
# b) ¿Cuál es la función del PMe del insumo A? ¿A partir de qué nivel de utilización
# del insumo A se presenta el rendimiento promedio decreciente?
# c) ¿A partir de qué punto se empieza a verificar el rendimiento total decreciente?
# d) Demuestre que cuando el PT alcanza el máximo el PMg es cero.
# e) Demuestre que cuando el PMe llega a su máximo, el PMg es igual al PMe.
# 1.2. Construir las funciones de PMe y PMg del insumo x a partir de la siguiente
# función de producción: f ( x , y )=x . y−0,2 x
# 2−0,8 y
# 2
# . Suponga que el factor y está
# fijo en 10 unidades. ¿Para qué valores de x serán el PMe y el PMg iguales a cero?
# Interprete en cada caso.
# 1.3. Describa cómo afectaría a la curva de productividad (función de producto total) de
# un insumo las siguientes situaciones:
# a) Un adelanto tecnológico (mejora en la tecnología disponible en ese momento).
# b) Una variación en el precio del insumo variable.
# c) Un incremento de la dotación disponible del insumo fijo.
# 1.4. En el punto de la curva de PMg de un insumo a partir del cual se empieza a
# verificar la ley de los rendimientos marginales decrecientes, la elasticidad producto del
# insumo es mayor a la unidad. ¿Verdadero o Falso? Justifique.
# 1.5. Cuando baja el Producto Total:
# a) El PMe del insumo variable es cero.
# b) El PMg del insumo variable es cero.
# c) El PMe del insumo variable es negativo.
# d) El PMe del insumo variable está disminuyendo.
# 1.6. Cuando el PMe es positivo pero está disminuyendo, el PMg podría:
# a) Estar decreciendo.
# b) Ser igual a cero.
# c) Ser negativo.
# d) Cualquiera de las anteriores es correcta.

# %% [markdown]
# ### Ejercicio 2
#
# 2.- Producción con todos los insumos variables
# 2.1. Dada la función de producción f ( x1
# , x2)=2x1
# x2 , encuentre la máxima
# producción sujeta a que los costos no superen las 100 unidades monetarias, sabiendo
# que los precios de los insumos son 1
# r  5
# y 2
# r  4
# .
#
# 2.2. Si una empresa está produciendo en un punto en el que el cociente entre la
# productividad marginal del trabajo y el salario es mayor al cociente entre la
# productividad marginal del capital y el interés, ¿qué puede hacer para reducir los costos
# y mantener el mismo nivel de producción?
# 2.3. Un empresario que produce un bien tiene una tecnología que viene representada por
# la siguiente función de producción: f ( x1
#
# , x2)=2ln x1+ln x2 . Si el precio al que puede
# vender su producto en el mercado asciende a $25 y los costos a los que se enfrentan son:
# 1
# x  $1
# ,
# 2
# x  $2 y tiene unos costos fijos de $5, se pide:
# a) ¿Cuál es la combinación óptima de insumos que maximiza su beneficio?
# b) ¿Qué nivel de producción se alcanza con esa combinación de insumos?
# c) ¿Cuál es el nivel máximo de beneficios al que llega el empresario?
# 2.4. Una empresa posee la siguiente función de producción: f ( x , y )=x
# b
# y
# 0,5 . Si la
# función tiene rendimientos decrecientes a escala, ¿cuál es el rango de variabilidad de b?
# 2.5. Si la elasticidad producto del insumo 1
# x
# y del insumo 2
# x
# (ω ω 1 2 y
#
# ) es igual a 0,5 y
#
# el 1 PMe x  3
#
# , el 2 PMe x  5
#
# y el precio del insumo 2
# x
# es de $5 ( 2
# r  5
# ): ¿cuál debería
#
# ser el precio del insumo 1
# x
# ( 1
# r
# ) para que el último peso gastado en él genere el mismo
#
# nivel de producto que el último peso gastado en 2
# x
# ?
#
# 2.6. En el óptimo del productor:
# a) La curva isocuanta es tangente a la curva de isocosto.
# b) La Relación Técnica de Sustitución (RTS) de un insumo por otro es igual al cociente
# de los precios relativos de esos insumos (Relación de intercambio del mercado).
# c) El cociente entre la productividad marginal de un insumo y su precio es igual para
# todos los insumos.
# d) Todas las opciones son correctas.
# 2.7. Para producir un producto se requiere de capital y trabajo. Con rendimientos
# constantes a escala, si se aumenta el trabajo empleado por unidad en un 10%,
# manteniendo constante el capital por unidad, el producto:
# a) Aumentará un 10%.
# b) Disminuirá un 10%.
# c) Aumentará más del 10%.
# d) Aumentará menos del 10%.
#
#
# 2.8. Un empresario desea alcanzar un nivel de producción de 150 unidades al menor
# costo posible y para lograrlo recurre a Ud. Si sabe que el empresario dispone de una
# tecnología que utiliza dos insumos y se resume en la función de producción
# Q ( x , y )=5 xy+x
# 2
# , que se enfrenta a unos costos fijos de $ 10 y los precios de cada
# uno de los insumos x e y son $ 2 y $ 4 respectivamente, ¿Qué cantidades de cada
# uno de los insumos le recomendaría utilizar? ¿A cuánto ascendería el costo total?
# 2.9. Dada la siguiente función de producción Cobb-Douglas: Q AX X1 2
#  
# 
#
# y sabiendo
#
# que  , 0 
#
# , que    1
#
# y que la función de costos viene dada por la expresión
# C r X r X b    1 1 2 2 . Se pide que calcule las funciones de demanda para cada uno de los
# insumos. (Ayuda: para facilitar las expresiones utilice       1
#
# en donde sea
#
# necesario).
# 2.10. ¿Qué se entiende por función de demanda condicionada o derivada de los
# factores? ¿Cómo se obtienen?

# %% [markdown]
# ### Ejercicio 3
#
# 3.- Teoría de los Costos
# 3.1. Si la función de costo total a corto plazo de un empresario es
# 3 2 CT q q q     0,04 0,9 10 5 , determine:
# a) ¿Cuál es el nivel de producto para el cual se maximiza el beneficio si el precio al que puede vender su producto es $ 4? ¿A cuánto asciende el beneficio en ese nivel?
# b) ¿Cuál es el precio mínimo al que el empresario debería colocar su producción para obtener unos beneficios no negativos?
# 3.2. La función de costo total de una empresa para la producción de un bien se expresa
# 3 2 CT aq bq cq    . Se pide:
# a) ¿A qué plazo se refiere la función? Justifique.
# b) Calcule las expresiones del costo medio y del costo marginal.
#
#
# 3.3. Supongamos que la función de costo total a corto plazo de un empresario es
# 3 2 CT q q q     10 17 66 . Determinar el nivel de producción para el que se maximiza
# el beneficio si el precio al que vende su producto asciende a $5. ¿Cuál es el beneficio
# que obtiene en ese punto?
# 3.4. Una empresa tiene una función de costos totales
#
# 2 CT q   10 1000 . Se pide:
#
# a) ¿En qué nivel de producción se minimiza el costo medio?
# b) Verifique que en el nivel averiguado en el punto anterior se igualan el costo medio y
# el marginal.
# 3.5. Pablo González planea abrir una juguetería en un shopping de próxima
# inauguración. Le ofrecen la posibilidad de elegir entre tres locales de diferente tamaño
#
#
# para alquilar: uno de 200 m2
#
# , otro de 500 m2
#
# y un tercero de 1.000 m2
#
# . En todos los
#
# casos el alquiler mensual será de $10 por metro cuadrado.
# Por la experiencia de sus anteriores emprendimientos, Pablo estima que con una
# superficie "S" y una venta de "q" ramos mensuales, sus costes variables por mes serán:
# CV (q)=q
# 2
# /S
#
# a) ¿Cuáles serán las funciones de coste marginal y medio para cada posible local en
# alquiler?
# 2. ¿Cuántos juguetes debería vender al mes para minimizar el coste medio en cada caso?
# 3. Si la venta mensual estimada por el Sr. González oscila entre 5000 y 6000 juguetes,
# ¿qué local debería alquilar?
